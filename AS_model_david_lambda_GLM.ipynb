# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
np.set_printoptions(threshold=sys.maxsize)
pd.set_option('display.max_columns', False)
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv('ADA_1sec_adtl.csv').set_index('system_time')
data.index = pd.to_datetime(data.index)

# %%
data.columns
# Out:
# Index(['midpoint', 'spread', 'buys', 'sells', 'bids_distance_0',
#        'bids_distance_1', 'bids_distance_2', 'bids_distance_3',
#        'bids_distance_4', 'bids_distance_5',
#        ...
#        'asks_patience', 'spread_rm', 'spread_rstd', 'time_sin', 'time_cos',
#        'signal_flow_mom', 'exec_imb', 'signal_exec_imb', 'long_imb_exploit',
#        'short_imb_exploit'],
#       dtype='object', length=194)

# %%
full_column_list = data.columns.to_list()
print(full_column_list)
# Out:
# ['midpoint', 'spread', 'buys', 'sells', 'bids_distance_0', 'bids_distance_1', 'bids_distance_2', 'bids_distance_3', 'bids_distance_4', 'bids_distance_5', 'bids_distance_6', 'bids_distance_7', 'bids_distance_8', 'bids_distance_9', 'bids_distance_10', 'bids_distance_11', 'bids_distance_12', 'bids_distance_13', 'bids_distance_14', 'bids_notional_0', 'bids_notional_1', 'bids_notional_2', 'bids_notional_3', 'bids_notional_4', 'bids_notional_5', 'bids_notional_6', 'bids_notional_7', 'bids_notional_8', 'bids_notional_9', 'bids_notional_10', 'bids_notional_11', 'bids_notional_12', 'bids_notional_13', 'bids_notional_14', 'bids_cancel_notional_0', 'bids_cancel_notional_1', 'bids_cancel_notional_2', 'bids_cancel_notional_3', 'bids_cancel_notional_4', 'bids_cancel_notional_5', 'bids_cancel_notional_6', 'bids_cancel_notional_7', 'bids_cancel_notional_8', 'bids_cancel_notional_9', 'bids_cancel_notional_10', 'bids_cancel_notional_11', 'bids_cancel_notional_12', 'bids_cancel_notional_13', 'bids_cancel_notional_14', 'bids_limit_notional_0', 'bids_limit_notional_1', 'bids_limit_notional_2', 'bids_limit_notional_3', 'bids_limit_notional_4', 'bids_limit_notional_5', 'bids_limit_notional_6', 'bids_limit_notional_7', 'bids_limit_notional_8', 'bids_limit_notional_9', 'bids_limit_notional_10', 'bids_limit_notional_11', 'bids_limit_notional_12', 'bids_limit_notional_13', 'bids_limit_notional_14', 'bids_market_notional_0', 'bids_market_notional_1', 'bids_market_notional_2', 'bids_market_notional_3', 'bids_market_notional_4', 'bids_market_notional_5', 'bids_market_notional_6', 'bids_market_notional_7', 'bids_market_notional_8', 'bids_market_notional_9', 'bids_market_notional_10', 'bids_market_notional_11', 'bids_market_notional_12', 'bids_market_notional_13', 'bids_market_notional_14', 'asks_distance_0', 'asks_distance_1', 'asks_distance_2', 'asks_distance_3', 'asks_distance_4', 'asks_distance_5', 'asks_distance_6', 'asks_distance_7', 'asks_distance_8', 'asks_distance_9', 'asks_distance_10', 'asks_distance_11', 'asks_distance_12', 'asks_distance_13', 'asks_distance_14', 'asks_notional_0', 'asks_notional_1', 'asks_notional_2', 'asks_notional_3', 'asks_notional_4', 'asks_notional_5', 'asks_notional_6', 'asks_notional_7', 'asks_notional_8', 'asks_notional_9', 'asks_notional_10', 'asks_notional_11', 'asks_notional_12', 'asks_notional_13', 'asks_notional_14', 'asks_cancel_notional_0', 'asks_cancel_notional_1', 'asks_cancel_notional_2', 'asks_cancel_notional_3', 'asks_cancel_notional_4', 'asks_cancel_notional_5', 'asks_cancel_notional_6', 'asks_cancel_notional_7', 'asks_cancel_notional_8', 'asks_cancel_notional_9', 'asks_cancel_notional_10', 'asks_cancel_notional_11', 'asks_cancel_notional_12', 'asks_cancel_notional_13', 'asks_cancel_notional_14', 'asks_limit_notional_0', 'asks_limit_notional_1', 'asks_limit_notional_2', 'asks_limit_notional_3', 'asks_limit_notional_4', 'asks_limit_notional_5', 'asks_limit_notional_6', 'asks_limit_notional_7', 'asks_limit_notional_8', 'asks_limit_notional_9', 'asks_limit_notional_10', 'asks_limit_notional_11', 'asks_limit_notional_12', 'asks_limit_notional_13', 'asks_limit_notional_14', 'asks_market_notional_0', 'asks_market_notional_1', 'asks_market_notional_2', 'asks_market_notional_3', 'asks_market_notional_4', 'asks_market_notional_5', 'asks_market_notional_6', 'asks_market_notional_7', 'asks_market_notional_8', 'asks_market_notional_9', 'asks_market_notional_10', 'asks_market_notional_11', 'asks_market_notional_12', 'asks_market_notional_13', 'asks_market_notional_14', 'avg_depth_bid_top3', 'depth_bid_0_5', 'depth_ask_0_5', 'imb_0', 'imb_1', 'imb_2', 'imb_3', 'imb_4', 'imb_5', 'imb_6', 'imb_7', 'imb_8', 'imb_9', 'imb_10', 'imb_11', 'imb_12', 'imb_13', 'imb_14', 'vw_dist_bid', 'flow_net_mkt', 'OFI', 'flow_net_mkt_sma_10', 'level_bids', 'level_asks', 'exec_impact_bid', 'exec_impact_ask', 'ret_1s', 'vol_30s', 'mom_5s', 'bids_patience', 'asks_patience', 'spread_rm', 'spread_rstd', 'time_sin', 'time_cos', 'signal_flow_mom', ' ...

# %%
volume_bids = pd.DataFrame()
volume_asks = pd.DataFrame()
for x in data.columns:
    if 'market' in x:
        if 'bid' in x:
            volume_bids[x] = data[x].copy()
        elif 'ask' in x:
            volume_asks[x] = data[x].copy()

# %%
data['midpoint'] /= 1000

# %%
# Filter rows where 'bids_market_notional_0' is less than the row-wise sum of all columns in 'volume_bids'
#if only the level 0 exceeds total, there's a problem
condition = volume_bids['bids_market_notional_0'] < volume_bids.sum(axis=1)
filtered_bids = volume_bids[condition]

# Compute the cumulative sum and normalize by the row-wise sum
normalized_bids = filtered_bids.cumsum(axis=1).div(filtered_bids.sum(axis=1), axis=0)

normalized_bids = normalized_bids.stack() #multiIndex
normalized_bids = normalized_bids[normalized_bids>=1].reset_index().groupby(['system_time' , 0]).first()
normalized_bids.reset_index(inplace=True)
normalized_bids['level_2'] = normalized_bids['level_1'].apply(lambda x: x.replace('market_notional', 'price'))
#normalized_bids

# %%
condition = volume_asks['asks_market_notional_0'] < volume_asks.sum(axis=1)

filtered_asks = volume_asks[condition]

normalized_asks = filtered_asks.cumsum(axis=1).div(filtered_asks.sum(axis=1), axis=0)

normalized_asks = normalized_asks.stack()
normalized_asks = normalized_asks[normalized_asks>=1].reset_index().groupby(['system_time' , 0]).first()
normalized_asks.reset_index(inplace=True)
normalized_asks['level_2'] = normalized_asks['level_1'].apply(lambda x: x.replace('market_notional', 'price'))

# %%
# Initialize empty DataFrames for storing bid and ask prices
prices_bids = pd.DataFrame()
prices_asks = pd.DataFrame()
#compute actual bids and prices
# Loop through the columns to calculate adjusted prices for bids and asks
for x in data.columns:
    if 'distance' in x:  # Look for columns with 'distance' in their names
        if 'bids' in x:  # For bid distances
            prices_bids[x.replace('distance', 'price')] = data['midpoint'] * (1 + data[x])
        else:  # For ask distances
            prices_asks[x.replace('distance', 'price')] = data['midpoint'] * (1 + data[x])

# %%
# Compute delta prices for bids and asks
#pick out executed price per second;
#now we have price for every second
delta_price_bids = pd.concat([prices_bids.stack(), normalized_bids.set_index(['system_time' , 'level_2'])[0]], axis=1
).dropna()
delta_price_bids = delta_price_bids.reset_index().iloc[:, [0, 2]]

# %%
delta_price_asks = pd.concat([prices_asks.stack(), normalized_asks.set_index(['system_time' , 'level_2'])[0]], axis=1
).dropna()
delta_price_asks = delta_price_asks.reset_index().iloc[:, [0, 2]]

# %%
# Create DataFrame for delta prices for bids
delta_price_bids = pd.DataFrame(
    delta_price_bids.set_index('system_time').values.T[0] -
    data.loc[delta_price_bids['system_time'],'midpoint']
)
# Create DataFrame for delta prices for asks
delta_price_asks = pd.DataFrame(
    delta_price_asks.set_index('system_time').values.T[0] -
    data.loc[delta_price_asks['system_time'] , 'midpoint']
)

# %%
data.head()
# Out:
#                                   midpoint  ...  short_imb_exploit
# system_time                                 ...
# 2021-04-07 11:33:00.055697+00:00  0.001171  ...              False
# 2021-04-07 11:33:01.055697+00:00  0.001170  ...              False
# 2021-04-07 11:33:02.055697+00:00  0.001170  ...              False
# 2021-04-07 11:33:03.055697+00:00  0.001170  ...              False
# 2021-04-07 11:33:04.055697+00:00  0.001170  ...              False
#
# [5 rows x 194 columns]

# %%
data['bid_fill'] = data['exec_impact_bid'].notnull().astype(int)
data['ask_fill'] = data['exec_impact_ask'].notnull().astype(int)

# %%
counts = pd.DataFrame({
    'bid_fills': data['bid_fill'].resample('1S').sum(),
    'ask_fills': data['ask_fill'].resample('1S').sum()
})
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\3288791594.py:2: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   'bid_fills': data['bid_fill'].resample('1S').sum(),
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\3288791594.py:3: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   'ask_fills': data['ask_fill'].resample('1S').sum()

# %%
features = data[[
    'spread', 
    'depth_bid_0_5', 'depth_ask_0_5',
    'imb_0', 'imb_1', 'imb_2',
    'vol_30s',
    'signal_flow_mom'
]]

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from tqdm import tqdm
import numpy as np

# %%
final_data_with_lags = pd.read_csv('final_data_with_lags.csv')

# %%
from statsmodels.api import GLM, add_constant
from statsmodels.genmod.families import Poisson
from sklearn.preprocessing import StandardScaler

# 1) Prepare X and y
features_sec = features.resample('1S').mean().ffill()
data_sec = counts.join(features_sec).dropna()

scaler = StandardScaler()
X = scaler.fit_transform(data_sec[features.columns])
X_sm = add_constant(X)       # statsmodels wants the intercept column added here

# 2) Fit GLM for bid fills
y_bid = data_sec['bid_fills']
glm_bid = GLM(y_bid, X_sm, family=Poisson())
glm_bid_results = glm_bid.fit()

# 3) Fit GLM for ask fills
y_ask = data_sec['ask_fills']
glm_ask = GLM(y_ask, X_sm, family=Poisson())
glm_ask_results = glm_ask.fit()

# 4) Predict per‐second arrival rates
data_sec['lambda_bid'] = glm_bid_results.predict(X_sm)
data_sec['lambda_ask'] = glm_ask_results.predict(X_sm)

# 5) (Optional) Inspect fit summaries
print(glm_bid_results.summary())
print(glm_ask_results.summary())

# 6) Now pass data_sec with its dynamic λ’s into your AS simulator:
#    avellaneda_stoikov(data_sec, gamma, T, rho, sigma, etc.)
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\842258370.py:6: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   features_sec = features.resample('1S').mean().ffill()
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              bid_fills   No. Observations:              1030572
# Model:                            GLM   Df Residuals:                  1030563
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.1243e+05
# Date:                Fri, 08 Aug 2025   Deviance:                   1.7552e+05
# Time:                        08:58:19   Pearson chi2:                 9.67e+05
# No. Iterations:                    13   Pseudo R-squ. (CS):           0.008347
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.8541      0.007   -551.179      0.000      -3.868      -3.840
# x1             0.0407      0.003     15.153      0.000       0.035       0.046
# x2             0.0165      0.005      3.325      0.001       0.007       0.026
# x3             0.0539      0.006      9.732      0.000       0.043       0.065
# x4             0.0184      0.007      2.807      0.005       0.006       0.031
# x5             0.0202      0.006      3.136      0.002       0.008       0.033
# x6             0.1122      0.006     17.504      0.000       0.100       0.125
# x7             0.1212      0.003     43.001      0.000       0.116       0.127
# x8             0.3907      0.006     69.296      0.000       0.380       0.402
# ==============================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:              ask_fills   No. Observations:              1030572
# Model:                            GLM   Df Residuals:                  1030563
# Model Family:                 Poisson   Df Model:                            8
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -3.0784e+05
# Date:                Fri, 08 Aug 2025   Deviance:                   4.3372e+05
# Time:                        08:58:19   Pearson chi2:                 9.18e+05
# No. Iterations:                    10   Pseudo R-squ. (CS):           0.007676
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.4527      0.003   -727.057      0.000      -2.459      -2.446
# x1             0.0195      0.002     10.110      0.000       0.016       0.023
# x2             0.0115      0.003      3.459      0.001       0.005       0.018
# x3            -0.0149      0.004     -4.045      0.000      -0.022      -0.008
# x4             0.0355      0.003     10.314      0.000       0.029       0.042
# x5            -0.0286      0.003     -8.451      0.000      -0.035      -0.022
# x6            -0.0803      0.003    -23.861      0.000      -0.087      -0.074
# x7             0.1254      0.002     67.523      0.000       0.122       0.129
# x8            -0.0902      0.003    -25.895      0.000      -0.097      -0.083
# ==============================================================================

# %%
y_ask = data_sec['ask_fills']
poisson_ask = sm.GLM(y_ask, X_sm, family=sm.families.Poisson()).fit()
data_sec['lambda_ask'] = poisson_ask.predict(X_sm)

# %%
data_sec[['lambda_bid', 'lambda_ask']].head(10)
# Out:
#                            lambda_bid  lambda_ask
# system_time
# 2021-04-07 11:33:30+00:00    0.017869    0.105417
# 2021-04-07 11:33:31+00:00    0.039318    0.090022
# 2021-04-07 11:33:32+00:00    0.016656    0.107785
# 2021-04-07 11:33:33+00:00    0.037699    0.096855
# 2021-04-07 11:33:34+00:00    0.053838    0.072249
# 2021-04-07 11:33:35+00:00    0.055230    0.073198
# 2021-04-07 11:33:36+00:00    0.052425    0.079362
# 2021-04-07 11:33:37+00:00    0.051229    0.074314
# 2021-04-07 11:33:38+00:00    0.041474    0.085898
# 2021-04-07 11:33:39+00:00    0.042824    0.082664

# %%
data_AS = pd.DataFrame(index=data.index)
prices = pd.DataFrame()

# Calculate adjusted prices
for x in data.columns:
    if 'distance' in x:
        prices[x.replace('distance', 'price')] = data['midpoint'] * (1 + data[x])

# Create a data frame with the required columns
data_AS[['midpoint', 'spread', 'buys', 'sells']] = data[['midpoint', 'spread', 'buys', 'sells']]
data_AS['farthest_bid'] = prices['bids_price_0']
data_AS['farthest_ask'] = prices['asks_price_0']

data_AS.loc[delta_price_asks.index, 'farthest_ask'] = delta_price_asks.iloc[:,0].values +data_AS.loc[delta_price_asks.index, 'midpoint']
data_AS.loc[delta_price_bids.index, 'farthest_bid'] = delta_price_bids.iloc[:,0].values +data_AS.loc[delta_price_bids.index, 'midpoint']

# %%
((1+data['bids_distance_0']) * data['midpoint'])[0]
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\331127772.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ((1+data['bids_distance_0']) * data['midpoint'])[0]
# np.float64(0.0011707491219374786)

# %%
train = pd.DataFrame()

for x in data.columns:
    if 'distance' in x:  # Look for columns with 'distance' in their names

      train[x.replace('distance', 'price')] = data['midpoint'] * (1 + data[x])
train['midpoint'] = data['midpoint']

# %%
actual_data = data.copy()
data = actual_data.copy()
#what does this do

# %%
import pandas as pd
import numpy as np

# Load the uploaded CSV file

# Function to calculate RSI
def calculate_rsi(data, column, window=14):
    delta = data[column].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

# Calculate RSI for the 'midpoint' column
data['RSI'] = calculate_rsi(data, 'midpoint')

# Scale bid/ask distances by midpoint
for i in range(10):
    data[f"asks_distance_{i}"] = data[f"asks_distance_{i}"] * data['midpoint']
    data[f"bids_distance_{i}"] = data[f"bids_distance_{i}"] * data['midpoint']

# Calculate Log Return
data['log_return'] = np.log(data['midpoint']).diff()

# Calculate Moving Average Return (window=5 as an example)
data['moving_avg_return'] = data['log_return'].rolling(window=5).mean()

# Calculate MACD components (12, 26, 9 periods)
short_ema = data['log_return'].ewm(span=10, adjust=False).mean()
long_ema = data['log_return'].ewm(span=50, adjust=False).mean()
data['macd'] = short_ema - long_ema * 100000
data['macd_signal'] = data['macd'].ewm(span=9, adjust=False).mean()





# Select relevant columns for the final dataset
selected_columns = ['midpoint', 'spread', 'buys', 'sells']
for i in range(3):
    selected_columns.append(f"bids_distance_{i}")
    selected_columns.append(f"asks_distance_{i}")

# Subset the data for selected features
final_data = data[selected_columns + [
    'RSI', 'log_return', 'moving_avg_return', 'macd', 'macd_signal'
]]

# %%
# Function to create lagged features
def create_lagged_features(data, lags=3, bid_ask_depth=3):
    """
    Add lagged features for bid/ask prices and returns to the dataset and define the next log return as the target.

    Parameters:
    - data: The DataFrame containing features.
    - lags: Number of lags for returns.
    - bid_ask_depth: Depth of bid/ask prices to lag.

    Returns:
    - DataFrame with lagged features added and next log return as the target.
    """
    lagged_features = {}

    # Create lagged features for bid/ask prices up to specified depth
    for i in range(bid_ask_depth):
        for lag in range(1, lags + 1):
            lagged_features[f'bids_distance_{i}_lag_{lag}'] = data[f'bids_distance_{i}'].shift(lag)
            lagged_features[f'asks_distance_{i}_lag_{lag}'] = data[f'asks_distance_{i}'].shift(lag)

    # Create lagged features for returns
    for lag in range(1, lags + 1):
        lagged_features[f'log_return_lag_{lag}'] = data['log_return'].shift(lag)

    # Add the next log return as the target
    data['next_log_return'] = data['log_return'].shift(-1)

    # Concatenate lagged features into the original DataFrame
    lagged_features_df = pd.concat(lagged_features, axis=1)
    data = pd.concat([data, lagged_features_df], axis=1)

    # Drop rows with NaN values due to lagging and target shifting
    data.dropna(inplace=True)

    return data


# Apply feature engineering
final_data_with_lags = create_lagged_features(final_data, lags=3, bid_ask_depth=3)
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\3711646771.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['next_log_return'] = data['log_return'].shift(-1)

# %%
final_data_with_lags = final_data_with_lags.dropna()

# %%
final_data_with_lags.to_csv('final_data_with_lags.csv')

# %%
final_data_with_lags = pd.read_csv('final_data_with_lags.csv')

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Define target variable and features
target = final_data_with_lags['next_log_return']
features = final_data_with_lags.drop(columns=['next_log_return'])

# Split data into train, validation, and test sets
n = len(features)
train_end = int(n * 0.8)  # 80% for training
val_end = int(n * 0.9)    # Next 10% for validation
test_end = n              # Final 10% for testing

X_train, y_train = features.iloc[:train_end], target.iloc[:train_end]
X_val, y_val = features.iloc[train_end:val_end], target.iloc[train_end:val_end]
X_test, y_test = features.iloc[val_end:test_end], target.iloc[val_end:test_end]

# Train the XGBoost model
xgb_model = XGBRegressor(
    n_estimators=200,
    learning_rate=0.05,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='rmse'  # Specify the evaluation metric here
)

# Fit the model with early stopping
xgb_model.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)],
    verbose=True
)

# Evaluate the model on the test set
y_test_pred = xgb_model.predict(X_test)
mse_test = mean_squared_error(y_test, y_test_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)

# Display evaluation metrics
print(f"Test Mean Squared Error (MSE): {mse_test}")
print(f"Test Mean Absolute Error (MAE): {mae_test}")

plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, y_test_pred, label='Predicted')
plt.xlabel('Test Index')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
#Plots of convergence of MSE and MAE
'''
plt.subplot(1, 2, 2)
plt.plot(y_test.index, progressive mae_test, label='MAE Convergence')
plt.plot(y_test.index, progressive mse_test, label = 'MSE Convergence')

'''
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# [0]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [1]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [2]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [3]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [4]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [5]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [6]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [7]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [8]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [9]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [10]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [11]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [12]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [13]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [14]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [15]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [16]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [17]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [18]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [19]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [20]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [21]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [22]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [23]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [24]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [25]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [26]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [27]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [28]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [29]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [30]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [31]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [32]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [33]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [34]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [35]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [36]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [37]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [38]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [39]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [40]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [41]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [42]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [43]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [44]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [45]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [46]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [47]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [48]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [49]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [50]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [51]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [52]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [53]	validation_0-rmse:0.00019	validation_1-rmse:0.00040
# [54]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [55]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [56]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [57]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [58]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [59]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [60]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [61]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [62]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [63]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [64]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [65]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [66]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [67]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [68]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [69]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [70]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [71]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [72]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [73]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [74]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [75]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [76]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [77]	validation_0-rmse:0.00019	validation_1-rmse:0.00041
# [78]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [79]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [80]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [81]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [82]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [83]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [84]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [85]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [86]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [87]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [88]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [89]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [90]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [91]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [92]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [93]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [94]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [95]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [96]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [97]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [98]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [99]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [100]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [101]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [102]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [103]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [104]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [105]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [106]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [107]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [108]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [109]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [110]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [111]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [112]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [113]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [114]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [115]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [116]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [117]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [118]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [119]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [120]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [121]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [122]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [123]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [124]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [125]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [126]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [127]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [128]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [129]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [130]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [131]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [132]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [133]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [134]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [135]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [136]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [137]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [138]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [139]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [140]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [141]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [142]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [143]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [144]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [145]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [146]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [147]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [148]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [149]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [150]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [151]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [152]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [153]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [154]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [155]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [156]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [157]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [158]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [159]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [160]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [161]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [162]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [163]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [164]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [165]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [166]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [167]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [168]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [169]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [170]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [171]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [172]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [173]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [174]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [175]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [176]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [177]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [178]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [179]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [180]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [181]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [182]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [183]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [184]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [185]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [186]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [187]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [188]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [189]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [190]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [191]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [192]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [193]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [194]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [195]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [196]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [197]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [198]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# [199]	validation_0-rmse:0.00018	validation_1-rmse:0.00041
# Test Mean Squared Error (MSE): 1.2244602271098557e-07
# Test Mean Absolute Error (MAE): 0.00019403946263858295

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test.index, y_test, label='Actual')
plt.plot(y_test.index, y_test_pred, label='Predicted')
plt.xlabel('Test Index')
plt.ylabel('Value')
plt.title('Actual vs. Predicted Values')
plt.legend()
#Plots of convergence of MSE and MAE
'''
plt.subplot(1, 2, 2)
plt.plot(y_test.index, progressive mae_test, label='MAE Convergence')
plt.plot(y_test.index, progressive mse_test, label = 'MSE Convergence')

'''

plt.show()

# %%
y_val_pred = xgb_model.predict(X_val)
# Calculate the correlation between the true and predicted values
correlation = np.corrcoef(y_val, y_val_pred)# Extract the correlation coefficient

correlation[0]
# Out:
# array([1.        , 0.10674705])

# %%
signal = pd.DataFrame(y_test_pred , columns=['signal'] , index=y_test.index)

# %%
start_idx = np.random.randint(0, len(signal) -3*3600 )
new_signal = signal.iloc[start_idx :3600*3+start_idx, :]
indices = new_signal.index

# %%
data_sec['lambda_ask']
# Out:
# system_time
# 2021-04-07 11:33:30+00:00    0.105417
# 2021-04-07 11:33:31+00:00    0.090022
# 2021-04-07 11:33:32+00:00    0.107785
# 2021-04-07 11:33:33+00:00    0.096855
# 2021-04-07 11:33:34+00:00    0.072249
#                                ...
# 2021-04-19 09:49:37+00:00    0.101988
# 2021-04-19 09:49:38+00:00    0.080720
# 2021-04-19 09:49:39+00:00    0.086050
# 2021-04-19 09:49:40+00:00    0.086238
# 2021-04-19 09:49:41+00:00    0.077976
# Freq: s, Name: lambda_ask, Length: 1030572, dtype: float64

# %%
data_sec[['lambda_bid','lambda_ask']].head()
# Out:
#                            lambda_bid  lambda_ask
# system_time
# 2021-04-07 11:33:30+00:00    0.017869    0.105417
# 2021-04-07 11:33:31+00:00    0.039318    0.090022
# 2021-04-07 11:33:32+00:00    0.016656    0.107785
# 2021-04-07 11:33:33+00:00    0.037699    0.096855
# 2021-04-07 11:33:34+00:00    0.053838    0.072249

# %%
data_AS
# Out:
#                                   midpoint  spread  ...  farthest_bid  farthest_ask
# system_time                                         ...
# 2021-04-07 11:33:00.055697+00:00  0.001171  0.0015  ...      0.001171      0.001171
# 2021-04-07 11:33:01.055697+00:00  0.001170  0.0001  ...      0.001170      0.001170
# 2021-04-07 11:33:02.055697+00:00  0.001170  0.0009  ...      0.001170      0.001170
# 2021-04-07 11:33:03.055697+00:00  0.001170  0.0001  ...      0.001170      0.001170
# 2021-04-07 11:33:04.055697+00:00  0.001170  0.0001  ...      0.001170      0.001170
# ...                                    ...     ...  ...           ...           ...
# 2021-04-19 09:49:37.442103+00:00  0.001271  0.0001  ...      0.001271      0.001271
# 2021-04-19 09:49:38.442103+00:00  0.001271  0.0001  ...      0.001271      0.001271
# 2021-04-19 09:49:39.442103+00:00  0.001271  0.0004  ...      0.001271      0.001271
# 2021-04-19 09:49:40.442103+00:00  0.001271  0.0001  ...      0.001271      0.001271
# 2021-04-19 09:49:41.442103+00:00  0.001271  0.0001  ...      0.001271      0.001271
#
# [1030533 rows x 6 columns]

# %%
data_sec[['lambda_bid','lambda_ask']].head()
# Out:
#                            lambda_bid  lambda_ask
# system_time
# 2021-04-07 11:33:30+00:00    0.017869    0.105417
# 2021-04-07 11:33:31+00:00    0.039318    0.090022
# 2021-04-07 11:33:32+00:00    0.016656    0.107785
# 2021-04-07 11:33:33+00:00    0.037699    0.096855
# 2021-04-07 11:33:34+00:00    0.053838    0.072249

# %%
data_sec.index
# Out:
# DatetimeIndex(['2021-04-07 11:33:30+00:00', '2021-04-07 11:33:31+00:00',
#                '2021-04-07 11:33:32+00:00', '2021-04-07 11:33:33+00:00',
#                '2021-04-07 11:33:34+00:00', '2021-04-07 11:33:35+00:00',
#                '2021-04-07 11:33:36+00:00', '2021-04-07 11:33:37+00:00',
#                '2021-04-07 11:33:38+00:00', '2021-04-07 11:33:39+00:00',
#                ...
#                '2021-04-19 09:49:32+00:00', '2021-04-19 09:49:33+00:00',
#                '2021-04-19 09:49:34+00:00', '2021-04-19 09:49:35+00:00',
#                '2021-04-19 09:49:36+00:00', '2021-04-19 09:49:37+00:00',
#                '2021-04-19 09:49:38+00:00', '2021-04-19 09:49:39+00:00',
#                '2021-04-19 09:49:40+00:00', '2021-04-19 09:49:41+00:00'],
#               dtype='datetime64[ns, UTC]', name='system_time', length=1030572, freq='s')

# %%
data_AS.index
# Out:
# DatetimeIndex(['2021-04-07 11:33:00.055697+00:00',
#                '2021-04-07 11:33:01.055697+00:00',
#                '2021-04-07 11:33:02.055697+00:00',
#                '2021-04-07 11:33:03.055697+00:00',
#                '2021-04-07 11:33:04.055697+00:00',
#                '2021-04-07 11:33:05.055697+00:00',
#                '2021-04-07 11:33:06.055697+00:00',
#                '2021-04-07 11:33:07.055697+00:00',
#                '2021-04-07 11:33:08.055697+00:00',
#                '2021-04-07 11:33:09.055697+00:00',
#                ...
#                '2021-04-19 09:49:32.442103+00:00',
#                '2021-04-19 09:49:33.442103+00:00',
#                '2021-04-19 09:49:34.442103+00:00',
#                '2021-04-19 09:49:35.442103+00:00',
#                '2021-04-19 09:49:36.442103+00:00',
#                '2021-04-19 09:49:37.442103+00:00',
#                '2021-04-19 09:49:38.442103+00:00',
#                '2021-04-19 09:49:39.442103+00:00',
#                '2021-04-19 09:49:40.442103+00:00',
#                '2021-04-19 09:49:41.442103+00:00'],
#               dtype='datetime64[ns, UTC]', name='system_time', length=1030533, freq=None)

# %%
data_AS = pd.merge(data_AS, data_sec[['lambda_bid','lambda_ask']], left_index=True, right_index=True, how='inner')

# %%
data_AS.index = data_AS.index.round('S')
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\427618088.py:1: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   data_AS.index = data_AS.index.round('S')

# %%
signal.index = signal.index.round('S')
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\2722229323.py:1: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   signal.index = signal.index.round('S')

# %%
data_AS.head()
# Out:
#                            midpoint  spread  ...  farthest_bid  farthest_ask
# system_time                                  ...
# 2021-04-07 11:33:00+00:00  0.001171  0.0015  ...      0.001171      0.001171
# 2021-04-07 11:33:01+00:00  0.001170  0.0001  ...      0.001170      0.001170
# 2021-04-07 11:33:02+00:00  0.001170  0.0009  ...      0.001170      0.001170
# 2021-04-07 11:33:03+00:00  0.001170  0.0001  ...      0.001170      0.001170
# 2021-04-07 11:33:04+00:00  0.001170  0.0001  ...      0.001170      0.001170
#
# [5 rows x 6 columns]

# %%
data_sec[['lambda_bid','lambda_ask']].head()
# Out:
#                            lambda_bid  lambda_ask
# system_time
# 2021-04-07 11:33:30+00:00    0.017869    0.105417
# 2021-04-07 11:33:31+00:00    0.039318    0.090022
# 2021-04-07 11:33:32+00:00    0.016656    0.107785
# 2021-04-07 11:33:33+00:00    0.037699    0.096855
# 2021-04-07 11:33:34+00:00    0.053838    0.072249

# %%
data_AS = data_AS.join(data_sec[['lambda_bid','lambda_ask']])

# %%
data_AS.dropna(inplace=True)

# %%
data_AS
# Out:
#                            midpoint  spread  ...  lambda_bid  lambda_ask
# system_time                                  ...
# 2021-04-07 11:33:30+00:00  0.001167  0.0006  ...    0.017869    0.105417
# 2021-04-07 11:33:31+00:00  0.001167  0.0012  ...    0.039318    0.090022
# 2021-04-07 11:33:32+00:00  0.001167  0.0004  ...    0.016656    0.107785
# 2021-04-07 11:33:33+00:00  0.001167  0.0009  ...    0.037699    0.096855
# 2021-04-07 11:33:34+00:00  0.001167  0.0009  ...    0.053838    0.072249
# ...                             ...     ...  ...         ...         ...
# 2021-04-19 09:49:37+00:00  0.001271  0.0001  ...    0.014972    0.101988
# 2021-04-19 09:49:38+00:00  0.001271  0.0001  ...    0.038004    0.080720
# 2021-04-19 09:49:39+00:00  0.001271  0.0004  ...    0.038266    0.086050
# 2021-04-19 09:49:40+00:00  0.001271  0.0001  ...    0.035528    0.086238
# 2021-04-19 09:49:41+00:00  0.001271  0.0001  ...    0.037134    0.077976
#
# [1030503 rows x 8 columns]

# %%
T = 1  # horizon
last_orders_from_us = 0  # last orders we served
price = data_AS.iloc[0]['midpoint']
q_tilde = 1  # target inventory
rho =correlation[0,1]
std_a =np.std(y_val_pred)
from tqdm import tqdm

gamma = 0.01  # aversion to risk
sigma = np.log(1 + data_AS['midpoint'].pct_change()).std()  # vol

# %%
#data_AS = data_AS.join(signal)

# %%
data_AS.dropna(inplace=True)

# %%
data_AS['signal']
# Out:
# system_time
# 2021-04-18 05:28:43+00:00    1.849211e-04
# 2021-04-18 05:28:44+00:00   -1.432583e-04
# 2021-04-18 05:28:45+00:00    1.074337e-04
# 2021-04-18 05:28:46+00:00    4.255410e-04
# 2021-04-18 05:28:47+00:00    2.976435e-05
#                                  ...
# 2021-04-19 09:49:36+00:00    1.848692e-06
# 2021-04-19 09:49:37+00:00   -8.559702e-07
# 2021-04-19 09:49:38+00:00   -1.309001e-05
# 2021-04-19 09:49:39+00:00   -5.905316e-05
# 2021-04-19 09:49:40+00:00   -4.087996e-05
# Name: signal, Length: 101746, dtype: float32

# %%
data_AS.head()
# Out:
#                            midpoint  spread  ...  lambda_ask    signal
# system_time                                  ...
# 2021-04-18 05:28:43+00:00   0.00122  0.0023  ...    0.164783  0.000185
# 2021-04-18 05:28:44+00:00   0.00122  0.0017  ...    0.119766 -0.000143
# 2021-04-18 05:28:45+00:00   0.00122  0.0024  ...    0.152509  0.000107
# 2021-04-18 05:28:46+00:00   0.00122  0.0022  ...    0.132734  0.000426
# 2021-04-18 05:28:47+00:00   0.00122  0.0021  ...    0.143196  0.000030
#
# [5 rows x 9 columns]

# %%
n = len(data_AS)
cashflow = np.zeros(n+1)
pnl = np.zeros(n+1)
orders = np.zeros(n+1)
quoting_spread = np.zeros(n+1)

# %%
sigma = np.log(1 + data_AS['midpoint'].pct_change()).std()

# %%
def as_update(row, gamma, T, rho, std, j):
    global cashflow, pnl, orders, quoting_spread

    price  = row['midpoint']
    alpha  = row['signal']
    lam_b  = row['lambda_bid']
    lam_a  = row['lambda_ask']
    sigma  = row['sigma']           # return vol per sqrt(sec)

    # carry-forward if λ missing
    if not np.isfinite(lam_b) or not np.isfinite(lam_a) or (lam_a + lam_b) <= 0:
        orders[j] = orders[j-1]
        cashflow[j] = cashflow[j-1]
        quoting_spread[j] = quoting_spread[j-1]
        pnl[j] = cashflow[j] + orders[j]*price
        return

    # --- spreads in ABSOLUTE units ---
    baseline    = 0.5 * row['spread'] * price    # <-- fixed units
    sigma_abs   = sigma * price                   # convert return vol → price vol
    risk_center = 0.5 * gamma * (sigma_abs**2) * T
    risk_inv    = gamma * (sigma_abs**2) * T * orders[j-1]

    deltaBid = max(baseline + risk_center + risk_inv, 0.0)
    deltaAsk = max(baseline + risk_center - risk_inv, 0.0)

    # reservation price skew
    r = price + T * rho * (sigma/std) * alpha * price

    bid_px = r - deltaBid
    ask_px = r + deltaAsk

    # probabilistic fills from λ, only if at/inside touch
    p_bid = 1 - np.exp(-lam_b * T)
    p_ask = 1 - np.exp(-lam_a * T)
    eps = 1e-12  # tiny tolerance
    nb_bid = 1 if (bid_px >= row['best_bid'] - eps and np.random.rand() < p_bid) else 0
    nb_ask = 1 if (ask_px <= row['best_ask'] + eps and np.random.rand() < p_ask) else 0

    orders[j]         = orders[j-1] + nb_bid - nb_ask
    quoting_spread[j] = deltaAsk + deltaBid
    cashflow[j]       = cashflow[j-1] + nb_ask*ask_px - nb_bid*bid_px
    pnl[j]            = cashflow[j] + orders[j]*price

# %%
std_a =np.std(y_val_pred)

# %%
from arch import arch_model
import pandas as pd
import numpy as np

# Prepare the data for GARCH model
log_returns = final_data_with_lags['log_return']

# Split into train, validation, and test sets (similar to XGBoost setup)
train_log_returns = log_returns.iloc[:train_end]
val_log_returns = log_returns.iloc[train_end:val_end]
test_log_returns = log_returns.iloc[val_end:test_end]

# Combine train and validation for GARCH training
train_val_log_returns = pd.concat([train_log_returns, val_log_returns])

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from arch import arch_model

# Rescale the log returns
scaling_factor = 1e4
scaled_train_val_log_returns = train_val_log_returns * scaling_factor
scaled_test_log_returns = test_log_returns * scaling_factor

# Fit the ARMA-GARCH model on training data
arma_garch_model = arch_model(
    scaled_train_val_log_returns,
    mean='AR',        # Use ARMA in the mean equation
    lags=2,           # Number of AR lags
    vol='Garch',      # GARCH for volatility
    p=1, q=1          # GARCH(1, 1)
)
fitted_model = arma_garch_model.fit(disp='off')  # Suppress training output
print(fitted_model.summary())

# Extract ARMA and GARCH parameters
omega = fitted_model.params['omega']
alpha = fitted_model.params['alpha[1]']
beta = fitted_model.params['beta[1]']
ar_coefficients = [fitted_model.params[f'log_return[{i+1}]'] for i in range(1,2,1)]

# Dynamic prediction
forecasts = []
arma_predictions = []
squared_residuals = []
last_variance = fitted_model.conditional_volatility.iloc[-1]**2 # Last variance from training
last_returns = list(scaled_train_val_log_returns[-2:])  # Last AR lags from training

# Iterate through test data for dynamic forecasting
for ret in scaled_test_log_returns:
    # Predict the ARMA mean
    arma_mean = sum(ar_coefficients[i] * last_returns[-(i+1)] for i in range(len(ar_coefficients)))
    arma_predictions.append(arma_mean)

    # Update the variance dynamically using the GARCH equation
    residual = ret - arma_mean
    last_variance = omega + alpha * (residual**2) + beta * last_variance

    # Calculate squared residuals
    squared_residual = residual**2
    squared_residuals.append(squared_residual)

    # Store the forecasted variance
    forecasts.append(last_variance)

    # Update AR lag list
    last_returns.append(ret)
    last_returns = last_returns[-2:]  # Keep only the last 2 lags

# Convert back to the original scale
forecasted_variances = [var / (scaling_factor**2) for var in forecasts]
forecasted_std_deviations = [np.sqrt(var) for var in forecasted_variances]
arma_predictions_original_scale = [pred / scaling_factor for pred in arma_predictions]
squared_residuals_original_scale = [res / (scaling_factor**2) for res in squared_residuals]

# Convert forecasts to a DataFrame
dynamic_forecasts = pd.DataFrame({
    'Forecasted_Mean': arma_predictions_original_scale,
    'Actual_Log_Returns': test_log_returns.values,
    'Forecasted_Variance': forecasted_variances,
    'Forecasted_Std_Deviation': forecasted_std_deviations,
    'Squared_Residuals': squared_residuals_original_scale
}, index=test_log_returns.index)
# Out:
#                            AR - GARCH Model Results
# ==============================================================================
# Dep. Variable:             log_return   R-squared:                       0.004
# Mean Model:                        AR   Adj. R-squared:                  0.004
# Vol Model:                      GARCH   Log-Likelihood:           -1.73876e+06
# Distribution:                  Normal   AIC:                       3.47753e+06
# Method:            Maximum Likelihood   BIC:                       3.47760e+06
#                                         No. Observations:               915709
# Date:                Fri, Aug 08 2025   Df Residuals:                   915706
# Time:                        16:33:21   Df Model:                            3
#                                     Mean Model
# =================================================================================
#                      coef    std err          t      P>|t|       95.0% Conf. Int.
# ---------------------------------------------------------------------------------
# Const          2.8477e-03  1.480e-03      1.925  5.428e-02 [-5.230e-05,5.748e-03]
# log_return[1]      0.0691  1.643e-03     42.086      0.000  [6.592e-02,7.236e-02]
# log_return[2] -1.6578e-03  1.532e-03     -1.082      0.279 [-4.660e-03,1.344e-03]
#                              Volatility Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# omega          0.0927  1.876e-02      4.941  7.775e-07 [5.594e-02,  0.129]
# alpha[1]       0.0911  8.659e-03     10.516  7.267e-26 [7.409e-02,  0.108]
# beta[1]        0.8922  1.129e-02     79.008      0.000   [  0.870,  0.914]
# ==========================================================================
#
# Covariance estimator: robust

# %%
signal = signal.copy()
signal['sigma'] = dynamic_forecasts['Forecasted_Std_Deviation'].to_numpy()

# %%
data_AS = data_AS.join(signal)

# %%
#AVELLANEDA STOIKOV LOOP
##AVELLANEDA STOIKOV LOOP
##AVELLANEDA STOIKOV LOOP
##AVELLANEDA STOIKOV LOOP
#

last_orders_from_us = 0
j = 1

for timestamp, row in data_AS.iterrows():
    
    # as_update will read last_orders_from_us, and write into cashflow, pnl, orders, quoting_spread
    as_update(row = row, gamma = gamma, T = T, rho = rho, std = std_a, j=j)
    
    # update inventory for next step
    last_orders_from_us = orders[j]
    j += 1

# %%
data_AS.shape
# Out:
# (101746, 12)

# %%
import numpy as np

def run_iterative_window(data_AS, signal, gamma, T, rho, std):
    # pick the exact timestamps to simulate
    idx = signal.index.intersection(data_AS.index)
    N = len(idx)

    # allocate globals the step uses
    global cashflow, pnl, orders, quoting_spread
    cashflow = np.zeros(N+1)
    pnl = np.zeros(N+1)
    orders = np.zeros(N+1)
    quoting_spread = np.zeros(N+1)

    # iterate
    for j, t in enumerate(idx, start=1):
        row = data_AS.loc[t]
        as_update(row, gamma=gamma, T=T, rho=rho, std=std, j=j)

    return pnl, cashflow, orders, quoting_spread

# ----- sample usage (random 3-hour window) -----
np.random.seed(42)
start_idx = np.random.randint(0, len(signal) - 3*3600)
new_signal = signal.iloc[start_idx:start_idx + 3*3600, :]   # must have columns ['signal'] and optionally ['sigma']

# IMPORTANT: ensure λ and σ exist on data_AS for this index
# data_AS['lambda_bid'], data_AS['lambda_ask'] already reindexed+ffilled
# For GARCH sigma per t:
# data_AS['sigma'] = signal['sigma'].reindex(data_AS.index, method='ffill')

pnl, cashflow, orders, quoting_spread = run_iterative_window(
    data_AS=data_AS, signal=new_signal, gamma=gamma, T=T, rho=0.0, std=std_a
)
print(pnl[-1])
# Out:
# -0.002262753958340566

# %%
np.random.seed(42)
pnl_with_alpha = []
pnl_without_alpha = []
pnl_garch = []

window_secs = 3 * 3600
for i in range(100):
    print(i)
    start_idx = np.random.randint(0, len(signal) - window_secs)
    window = slice(start_idx, start_idx + window_secs)

    # --- 1) With alpha only (constant sigma) ---
    # make a view with only 'signal' so as_update uses constant σ (ensure data_AS['sigma'] is set to a constant)
    new_signal_alpha_only = signal.iloc[window, :][['signal']].copy()

    # if you want constant σ here, set data_AS['sigma'] to scalar on-the-fly (optional):
    # data_AS.loc[new_signal_alpha_only.index, 'sigma'] = sigma_const

    pnl, *_ = run_iterative_window(
        data_AS=data_AS, signal=new_signal_alpha_only, gamma=gamma, T=T, rho=rho, std=std_a
    )
    pnl_with_alpha.append(pnl[-1])

    # --- 2) Without alpha (rho = 0) ---
    new_signal_no_alpha = signal.iloc[window, :].copy()
    pnl, *_ = run_iterative_window(
        data_AS=data_AS, signal=new_signal_no_alpha, gamma=gamma, T=T, rho=0.0, std=std_a
    )
    pnl_without_alpha.append(pnl[-1])
    print(pnl[-1])

    # --- 3) Alpha + GARCH (dynamic σ) ---
    # ensure signal has 'sigma' column for this window
    new_signal_garch = signal.iloc[window, :].copy()  # must include ['signal','sigma']
    # and make sure data_AS['sigma'] is aligned already:
    # data_AS['sigma'] = signal['sigma'].reindex(data_AS.index, method='ffill')

    pnl, *_ = run_iterative_window(
        data_AS=data_AS, signal=new_signal_garch, gamma=gamma, T=T, rho=rho, std=std_a
    )
    pnl_garch.append(pnl[-1])
# Out:
# 0
# -0.0029877725568543123
# 1
# 0.0005421823007037904
# 2
# -0.0016237781968775206
# 3
# -0.001007117080262937
# 4
# 0.0006155587287602488
# 5
# 0.0004887439660948567
# 6
# -0.0016812275718871145
# 7
# 0.00030644012786353036
# 8
# -0.002329394359106146
# 9
# -0.0032891133798665373
# 10
# -0.0008280534400450651
# 11
# -0.002218100351757707
# 12
# -0.0037114719031006993
# 13
# -0.002626161700640256
# 14
# 0.00038975633532854076
# 15
# 0.00012094435791921293
# 16
# -0.0008251620444805069
# 17
# 8.843357687209064e-05
# 18
# 0.00017981345417431016
# 19
# -0.0012800255745109845
# 20
# -0.0010102841258115697
# 21
# -0.0025914543058502965
# 22
# 0.00027859216400325654
# 23
# 0.0006978729305100184
# 24
# -0.0007359366585301674
# 25
# 0.0006401992353774616
# 26
# -0.0006841356177008789
# 27
# 0.0009062170566848382
# 28
# 0.00039024959249830266
# 29
# -0.002490652463254195
# 30
# -0.00076242141481489
# 31
# -0.005061415707567962
# 32
# -0.0012435883888336219
# 33
# 0.0008263283432845409
# 34
# -0.0007286157599890597
# 35
# -0.0009201931426741777
# 36
# -0.0007291499150365449
# 37
# -0.00028307637678028075
# 38
# -0.0009894162271036483
# 39
# -0.00040025131618652565
# 40
# -0.0002256025280548829
# 41
# -0.0002626813288321844
# 42
# -0.00011515166583703218
# 43
# 0.002532193766987434
# 44
# 0.0015273287716919548
# 45
# 1.3840608136708732e-05
# 46
# 0.00034091969288948393
# 47
# -0.001080583119327419
# 48
# 0.0012079502026916128
# 49
# 0.0004212357741863876
# 50
# -0.0004273756856082028
# 51
# -0.00019301993535104922
# 52
# -0.0034826817242216285
# 53
# -0.0007690388857413966
# 54
# 0.0008703861329795795
# 55
# -0.001281221269689714
# 56
# -0.005779979880532388
# 57
# -0.0022343941353020896
# 58
# 0.001403580846878437
# 59
# -0.003580927284754079
# 60
# -0.0005586489401364497
# 61
# -0.002366412390953934
# 62
# 0.0006491513390154552
# 63
# -0.0014767166678198163
# 64
# -0.0005352857510921016
# 65
# 0.0003971714981045038
# 66
# -0.0005266758871516758
# 67
# 0.00025396339966318737
# 68
# -0.001076064982975855
# 69
# -0.0005437088078063118
# 70
# 0.0017408266841327236
# 71
# -0.0007449489308404833
# 72
# -0.00101166947792046
# 73
# 0.00012029635450709619
# 74
# 1.5784048180048083e-05
# 75
# -0.0006229970866806628
# 76
# -0.0004805731181960621
# 77
# -0.0001183961783482873
# 78
# -0.0032773404981682602
# 79
# -0.00021111230068583675
# 80
# 0.0014269328070650594
# 81
# -0.002952760793173706
# 82
# -0.0012485760229646037
# 83
# -0.002278224169664528
# 84
# 0.0017211925826361024
# 85
# -0.003520532111150193
# 86
# -0.0025459641061288257
# 87
# -0.0002728166946729116
# 88
# -0.0013450283009632247
# 89
# 0.00011613613596626882
# 90
# -0.0001106366186478247
# 91
# 0.00047218825337172476
# 92
# 0.0005855617558914034
# 93
# -0.0035841879253890457
# 94
# -0.0028926466988916655
# 95
# 0.00014670326969790093
# 96
# -0.00019066579150370244
# 97
# -0.0008512806327924671
# 98
# -0.00045178684766411514
# 99
# -0.005707215661859055

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dawan\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dawan\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dawan\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dawan\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# prompt: plot distribution of pnl_with_alpha and pnl_without_alpha with kernel

import seaborn as sns

# Assuming pnl_with_alpha and pnl_without_alpha are already defined
plt.figure(figsize=(12, 6))
sns.kdeplot(pnl_with_alpha, label='Pnl with Alpha', shade=True)
sns.kdeplot(pnl_without_alpha, label='Pnl without Alpha', shade=True)
sns.kdeplot(pnl_garch, label='Pnl with Garch', shade=True)
plt.xlabel('Pnl')
plt.ylabel('Density')
plt.title('Pnl for Different Methods')
plt.legend()


plt.show()
# Out:
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\1743824162.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(pnl_with_alpha, label='Pnl with Alpha', shade=True)
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\1743824162.py:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(pnl_without_alpha, label='Pnl without Alpha', shade=True)
# C:\Users\dawan\AppData\Local\Temp\ipykernel_1536\1743824162.py:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(pnl_garch, label='Pnl with Garch', shade=True)
